# %%
print("hello word")
# Out:
# hello word

# %%
import pandas as pd
df1 = pd.read_csv('aqx_p_488.csv')
df2 = df1[['sitename','county','aqi','status','pm2.5_avg']]
df2
# Out:
#     sitename county   aqi status  pm2.5_avg
# 0         麥寮    雲林縣  49.0     良好       14.0
# 1         關山    臺東縣  26.0     良好        8.0
# 2         馬公    澎湖縣  36.0     良好       11.0
# 3         金門    金門縣  42.0     良好       13.0
# 4         馬祖    連江縣  69.0     普通       23.0
# ..       ...    ...   ...    ...        ...
# 995       陽明    臺北市  12.0     良好        1.0
# 996       花蓮    花蓮縣  26.0     良好        8.0
# 997       臺東    臺東縣  17.0     良好        3.0
# 998       潮州    屏東縣  99.0     普通       35.0
# 999       屏東    屏東縣  97.0     普通       34.0
#
# [1000 rows x 5 columns]

# %%
df2.columns = ["站點","城市","aqi","狀態","pm25"]
df2
# Out:
#      站點   城市   aqi  狀態  pm25
# 0    麥寮  雲林縣  49.0  良好  14.0
# 1    關山  臺東縣  26.0  良好   8.0
# 2    馬公  澎湖縣  36.0  良好  11.0
# 3    金門  金門縣  42.0  良好  13.0
# 4    馬祖  連江縣  69.0  普通  23.0
# ..   ..  ...   ...  ..   ...
# 995  陽明  臺北市  12.0  良好   1.0
# 996  花蓮  花蓮縣  26.0  良好   8.0
# 997  臺東  臺東縣  17.0  良好   3.0
# 998  潮州  屏東縣  99.0  普通  35.0
# 999  屏東  屏東縣  97.0  普通  34.0
#
# [1000 rows x 5 columns]

# %%
df2.to_csv('out.csv')

# %%
df2.to_excel('result2.xlsx',sheet_name='2024_06_27')
